# %%
from bs4 import BeautifulSoup
import requests
import csv

# %%
authors_m="https://www.aldiwan.net/authers-1"
authors_f="https://www.aldiwan.net/authers-2"

# %%
source = requests.get(authors_m).text
soup = BeautifulSoup(source, 'lxml')

# %%
import re

# %%
soup.find_all("a", href=re.compile("cat-poet.*"))
# Out:
# [<a href="cat-poet-Abu-al-Khair-al-Tabbaa">
#  <img alt="avatar" class="rounded-circle" height="100" src="https://www.aldiwan.net/public/images/profile/noimage.jpg" width="100"/>
#  </a>,
#  <a href="cat-poet-Abu-al-Khair-al-Tabbaa" style="color:#000;">
#  <span class="h3"> أبو الخير الطباع</span>
#  </a>,
#  <a href="cat-poet-Abu-Al-Hussein-Al-Nouri">
#  <img alt="avatar" class="rounded-circle" height="100" src="https://www.aldiwan.net/public/images/profile/noimage.jpg" width="100"/>
#  </a>,
#  <a href="cat-poet-Abu-Al-Hussein-Al-Nouri" style="color:#000;">
#  <span class="h3"> أبو الحسين النوري</span>
#  </a>,
#  <a href="cat-poet-Abul-Hasan-Al-Jurjani">
#  <img alt="avatar" class="rounded-circle" height="100" src="https://www.aldiwan.net/public/images/profile/noimage.jpg" width="100"/>
#  </a>,
#  <a href="cat-poet-Abul-Hasan-Al-Jurjani" style="color:#000;">
#  <span class="h3"> أبو الحسن الجرجاني</span>
#  </a>,
#  <a href="cat-poet-Abu-al-Assad-al-Hamani">
# ...

# %%
links=[f"https://www.aldiwan.net/authers-1?page={idx}" for idx in range(1,28)]
print(links)
# Out:
# ['https://www.aldiwan.net/authers-1?page=1', 'https://www.aldiwan.net/authers-1?page=2', 'https://www.aldiwan.net/authers-1?page=3', 'https://www.aldiwan.net/authers-1?page=4', 'https://www.aldiwan.net/authers-1?page=5', 'https://www.aldiwan.net/authers-1?page=6', 'https://www.aldiwan.net/authers-1?page=7', 'https://www.aldiwan.net/authers-1?page=8', 'https://www.aldiwan.net/authers-1?page=9', 'https://www.aldiwan.net/authers-1?page=10', 'https://www.aldiwan.net/authers-1?page=11', 'https://www.aldiwan.net/authers-1?page=12', 'https://www.aldiwan.net/authers-1?page=13', 'https://www.aldiwan.net/authers-1?page=14', 'https://www.aldiwan.net/authers-1?page=15', 'https://www.aldiwan.net/authers-1?page=16', 'https://www.aldiwan.net/authers-1?page=17', 'https://www.aldiwan.net/authers-1?page=18', 'https://www.aldiwan.net/authers-1?page=19', 'https://www.aldiwan.net/authers-1?page=20', 'https://www.aldiwan.net/authers-1?page=21', 'https://www.aldiwan.net/authers-1?page=22', 'https://www.ald
# ...

# %%
for i,poet_info in enumerate(soup.find_all("a", href=re.compile("cat-poet.*"))):
    poet_link=f'www.aldiwan.net/{poet_info["href"]}'
    if poet_info.span:
        poet_name=poet_info.span.text
        print(i,poet_name,poet_link)
# Out:
# 1  أبو الخير الطباع www.aldiwan.net/cat-poet-Abu-al-Khair-al-Tabbaa
# 3  أبو الحسين النوري www.aldiwan.net/cat-poet-Abu-Al-Hussein-Al-Nouri
# 5  أبو الحسن الجرجاني www.aldiwan.net/cat-poet-Abul-Hasan-Al-Jurjani
# 7  أبو الأسد الحماني www.aldiwan.net/cat-poet-Abu-al-Assad-al-Hamani
# 9  أبزون العماني www.aldiwan.net/cat-poet-Omani-Abzon
# 11  دوسر بن هذيل www.aldiwan.net/cat-poet-Dosser-bin-Hadeel
# 13  أبو وجزة السعدي www.aldiwan.net/cat-poet-Abu-Wajza-AlSaadi
# 15  إبراهيم الأكرمي www.aldiwan.net/cat-poet-Ibrahim-Al-Akrami
# 17  الحر العاملي www.aldiwan.net/cat-poet-Al-Hurr-al-Amili
# 19  أبو زبيد الطائي www.aldiwan.net/cat-poet-Abu-Zubaid-Al-Taie
# 21  الواساني www.aldiwan.net/cat-poet-Alwasani
# 23  وديع عقل www.aldiwan.net/cat-poet-Wadih-AKL
# 25  علي الغراب الصفاقسي www.aldiwan.net/cat-poet-Ali-Ghorab-Sfaxien
# 27  ابن بقي القرطبي www.aldiwan.net/cat-poet-Ibn-Baqy-Al-Qurtubi
# 29  أبو نخيلة www.aldiwan.net/cat-poet-Abu-Nakhila
# ...

# %%
poet_info=soup.find("div", class_=re.compile("col-6 col-md-8 px-0 text-center.*"))
# print(poet_info)
poet_link=f'www.aldiwan.net/{poet_info.a["href"]}'
poet_name=poet_info.span.text
print(poet_name,poet_link)
# Out:
#  أبو الخير الطباع www.aldiwan.net/cat-poet-Abu-al-Khair-al-Tabbaa

# %%
for i,poet_info in enumerate(soup.find_all("div", class_=re.compile("col-6 col-md-8 px-0 text-center.*"))):
    poet_link=f'www.aldiwan.net/{poet_info.a["href"]}'
    poet_name=poet_info.span.text
    print(i,poet_name,poet_link)
# Out:
# 0  أبو الخير الطباع www.aldiwan.net/cat-poet-Abu-al-Khair-al-Tabbaa
# 1  أبو الحسين النوري www.aldiwan.net/cat-poet-Abu-Al-Hussein-Al-Nouri
# 2  أبو الحسن الجرجاني www.aldiwan.net/cat-poet-Abul-Hasan-Al-Jurjani
# 3  أبو الأسد الحماني www.aldiwan.net/cat-poet-Abu-al-Assad-al-Hamani
# 4  أبزون العماني www.aldiwan.net/cat-poet-Omani-Abzon
# 5  دوسر بن هذيل www.aldiwan.net/cat-poet-Dosser-bin-Hadeel
# 6  أبو وجزة السعدي www.aldiwan.net/cat-poet-Abu-Wajza-AlSaadi
# 7  إبراهيم الأكرمي www.aldiwan.net/cat-poet-Ibrahim-Al-Akrami
# 8  الحر العاملي www.aldiwan.net/cat-poet-Al-Hurr-al-Amili
# 9  أبو زبيد الطائي www.aldiwan.net/cat-poet-Abu-Zubaid-Al-Taie
# 10  الواساني www.aldiwan.net/cat-poet-Alwasani
# 11  وديع عقل www.aldiwan.net/cat-poet-Wadih-AKL
# 12  علي الغراب الصفاقسي www.aldiwan.net/cat-poet-Ali-Ghorab-Sfaxien
# 13  ابن بقي القرطبي www.aldiwan.net/cat-poet-Ibn-Baqy-Al-Qurtubi
# 14  أبو نخيلة www.aldiwan.net/cat-poet-Abu-Nakhila
# ...

# %%
print(poet_info)
# Out:
# <a href="cat-poet-Abu-al-Khair-al-Tabbaa">
# <img alt="avatar" class="rounded-circle" height="100" src="https://www.aldiwan.net/public/images/profile/noimage.jpg" width="100"/>
# </a>

# %%
poets_info=soup.find_all("div", class_="col-6 col-md-8 px-0 text-center")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="rtl" lang="ar">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <title>
#    شعراء الفصحى - الشعراء - الديوان
#   </title>
#   <link crossorigin="anonymous" href="https://stackpath.bootstrapcdn.com/bootstrap/4.4.1/css/bootstrap.min.css" integrity="sha384-Vkoo8x4CGsO3+Hhxv8T/Q5PaXtkKtu6ug5TOeNV6gBiFeWPGFN9MuhOf23Q9Ifjh" rel="stylesheet"/>
#   <link crossorigin="" href="https://fonts.gstatic.com/" rel="preconnect"/>
#   <link href="https://www.aldiwan.net/public/css/all.min.css" rel="stylesheet"/>
#   <link href="https://use.fontawesome.com/releases/v5.13.0/css/v4-shims.css" rel="stylesheet"/>
#   <link href="https://fonts.googleapis.com/css?family=Amiri:400,700&amp;subset=arabic" rel="stylesheet"/>
# ...

# %%
csv_file = open('cms_scrape.csv', 'w')

csv_writer = csv.writer(csv_file)
csv_writer.writerow(['headline', 'summary', 'video_link'])

for article in soup.find_all('article'):
    headline = article.h2.a.text
    print(headline)

    summary = article.find('div', class_='entry-content').p.text
    print(summary)

    try:
        vid_src = article.find('iframe', class_='youtube-player')['src']

        vid_id = vid_src.split('/')[4]
        vid_id = vid_id.split('?')[0]

        yt_link = f'https://youtube.com/watch?v={vid_id}'
    except Exception as e:
        yt_link = None

    print(yt_link)

    print()

    csv_writer.writerow([headline, summary, yt_link])

csv_file.close()

# %%
a = { "a" : 1, "b" : 2 }
b = { "c" : 3, "d" : 4 }
# Out:
# {'a': 1, 'b': 2}

# %%
a.update(b)
# Out:
# None

# %%
a
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
import logging
logging.getLogger().setLevel(logging.INFO)
logging.debug('This is a debug message')
logging.info('This is an info message')
logging.warning('This is a warning message')
logging.error('This is an error message')
logging.critical('This is a critical message')
# Out:
# INFO:root:This is an info message
# WARNING:root:This is a warning message
# ERROR:root:This is an error message
# CRITICAL:root:This is a critical message
